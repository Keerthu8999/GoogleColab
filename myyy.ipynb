# %% [markdown]
# <a href="https://colab.research.google.com/github/Keerthu8999/GoogleColab/blob/main/myyy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers seqeval\[gpu\]

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer, BertConfig, BertForTokenClassification
import math
# this ensures that the current MacOS version is at least 12.3+
print(torch.backends.mps.is_available())
# this ensures that the current current PyTorch installation was built with MPS activated.
print(torch.backends.mps.is_built())
from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'
print(device)
# Out:
# False
# False
# cuda

# %%
data = pd.read_csv("/content/sample_data/ner_datasetreference-2.csv", encoding='unicode_escape')
print("Number of tags: {}".format(len(data.Tag.unique())))
frequencies = data.Tag.value_counts()
frequencies
# Out:
# Number of tags: 17
# O        887908
# B-geo     37644
# B-tim     20333
# B-org     20143
# I-per     17251
# B-per     16990
# I-org     16784
# B-gpe     15870
# I-geo      7414
# I-tim      6528
# B-art       402
# B-eve       308
# I-art       297
# I-eve       253
# B-nat       201
# I-gpe       198
# I-nat        51
# Name: Tag, dtype: int64

# %%
tags = {}
for tag, count in zip(frequencies.index, frequencies):
    if tag != "O":
        if tag[2:5] not in tags.keys():
            tags[tag[2:5]] = count
        else:
            tags[tag[2:5]] += count
    continue

print(sorted(tags.items(), key=lambda x: x[1], reverse=True))
# Out:
# [('geo', 45058), ('org', 36927), ('per', 34241), ('tim', 26861), ('gpe', 16068), ('art', 699), ('eve', 561), ('nat', 252)]

# %%
entities_to_remove = ["B-art", "I-art", "B-eve", "I-eve", "B-nat", "I-nat"]
data = data[~data.Tag.isin(entities_to_remove)]
data = data.fillna(method='ffill')
data['sentence'] = data[['Sentence #','Word','Tag']].groupby(['Sentence #'])['Word'].transform(lambda x: ' '.join(x))
data['word_labels'] = data[['Sentence #','Word','Tag']].groupby(['Sentence #'])['Tag'].transform(lambda x: ','.join(x))

# %%
label2id = {k: v for v, k in enumerate(data.Tag.unique())}
id2label = {v: k for v, k in enumerate(data.Tag.unique())}
label2id
data = data[["sentence", "word_labels"]].drop_duplicates().reset_index(drop=True)

# %%
MAX_LEN = 128
TRAIN_BATCH_SIZE = 4
VALID_BATCH_SIZE = 2
EPOCHS = 3
LEARNING_RATE = 1e-05
MAX_GRAD_NORM = 10
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
def tokenize_and_preserve_labels(sentence, text_labels, tokenizer):
    tokenized_sentence = []
    labels = []
    sentence = sentence.strip()
    for word, label in zip(sentence.split(), text_labels.split(",")):
        tokenized_word = tokenizer.tokenize(word)
        n_subwords = len(tokenized_word)
        tokenized_sentence.extend(tokenized_word)
        labels.extend([label] * n_subwords)
    return tokenized_sentence, labels

# %%
class dataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_len):
        self.len = len(dataframe)
        self.data = dataframe
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __getitem__(self, index):
        sentence = self.data.sentence[index]
        word_labels = self.data.word_labels[index]
        tokenized_sentence, labels = tokenize_and_preserve_labels(sentence, word_labels, self.tokenizer)
        tokenized_sentence = ["[CLS]"] + tokenized_sentence + ["[SEP]"]
        labels.insert(0, "O")
        labels.insert(-1, "O")
        maxlen = self.max_len
        if (len(tokenized_sentence) > maxlen):
          tokenized_sentence = tokenized_sentence[:maxlen]
          labels = labels[:maxlen]
        else:
          tokenized_sentence = tokenized_sentence + ['[PAD]'for _ in range(maxlen - len(tokenized_sentence))]
          labels = labels + ["O" for _ in range(maxlen - len(labels))]
        attn_mask = [1 if tok != '[PAD]' else 0 for tok in tokenized_sentence]
        ids = self.tokenizer.convert_tokens_to_ids(tokenized_sentence)

        label_ids = [label2id[label] for label in labels]
        return {
              'ids': torch.tensor(ids, dtype=torch.long),
              'mask': torch.tensor(attn_mask, dtype=torch.long),
              #'token_type_ids': torch.tensor(token_ids, dtype=torch.long),
              'targets': torch.tensor(label_ids, dtype=torch.long)
        }
    def __len__(self):
        return self.len

# %%
train_size = 0.8
train_dataset = data.sample(frac=train_size,random_state=200)
test_dataset = data.drop(train_dataset.index).reset_index(drop=True)
train_dataset = train_dataset.reset_index(drop=True)

print("FULL Dataset: {}".format(data.shape))
print("TRAIN Dataset: {}".format(train_dataset.shape))
print("TEST Dataset: {}".format(test_dataset.shape))

training_set = dataset(train_dataset, tokenizer, MAX_LEN)
testing_set = dataset(test_dataset, tokenizer, MAX_LEN)
# Out:
# FULL Dataset: (47571, 2)
# TRAIN Dataset: (38057, 2)
# TEST Dataset: (9514, 2)

# %%
train_params = {'batch_size': TRAIN_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

test_params = {'batch_size': VALID_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

training_loader = DataLoader(training_set, **train_params)
testing_loader = DataLoader(testing_set, **test_params)

# %%
model = BertForTokenClassification.from_pretrained('bert-base-uncased',
                                                   num_labels=len(id2label),
                                                   id2label=id2label,
                                                   label2id=label2id)
model.to(device)
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForTokenClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=11, bias=True)
# )

# %%
ids = training_set[0]["ids"].unsqueeze(0)
mask = training_set[0]["mask"].unsqueeze(0)
targets = training_set[0]["targets"].unsqueeze(0)
ids = ids.to(device)
mask = mask.to(device)
targets = targets.to(device)
outputs = model(input_ids=ids, attention_mask=mask, labels=targets)
initial_loss = outputs[0]
tr_logits = outputs[1]
optimizer = torch.optim.Adam(params=model.parameters(), lr=LEARNING_RATE)

# %%
def train(epoch):
    tr_loss, tr_accuracy = 0, 0
    nb_tr_examples, nb_tr_steps = 0, 0
    tr_preds, tr_labels = [], []
    model.train()
    for idx, batch in enumerate(training_loader):
        ids = batch['ids'].to(device, dtype = torch.long)
        mask = batch['mask'].to(device, dtype = torch.long)
        targets = batch['targets'].to(device, dtype = torch.long)
        outputs = model(input_ids=ids, attention_mask=mask, labels=targets)
        loss, tr_logits = outputs.loss, outputs.logits
        tr_loss += loss.item()
        nb_tr_steps += 1
        nb_tr_examples += targets.size(0)
        if idx % 100==0:
            loss_step = tr_loss/nb_tr_steps
            print(f"Training loss per 100 training steps: {loss_step}")
        flattened_targets = targets.view(-1)
        active_logits = tr_logits.view(-1, model.num_labels)
        flattened_predictions = torch.argmax(active_logits, axis=1)
        active_accuracy = mask.view(-1) == 1
        targets = torch.masked_select(flattened_targets, active_accuracy)
        predictions = torch.masked_select(flattened_predictions, active_accuracy)
        tr_preds.extend(predictions)
        tr_labels.extend(targets)
        tmp_tr_accuracy = accuracy_score(targets.cpu().numpy(), predictions.cpu().numpy())
        tr_accuracy += tmp_tr_accuracy
        torch.nn.utils.clip_grad_norm_(
            parameters=model.parameters(), max_norm=MAX_GRAD_NORM
        )
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    epoch_loss = tr_loss / nb_tr_steps
    tr_accuracy = tr_accuracy / nb_tr_steps
    print(f"Training loss epoch: {epoch_loss}")
    print(f"Training accuracy epoch: {tr_accuracy}")

# %%
for epoch in range(EPOCHS):
    print(f"Training epoch: {epoch + 1}")
    train(epoch)
# Out:
# Training epoch: 1
# Training loss per 100 training steps: 2.3849332332611084
# Training loss per 100 training steps: 0.40728571760182336
# Training loss per 100 training steps: 0.2677484437526755
# Training loss per 100 training steps: 0.21026031402530662
# Training loss per 100 training steps: 0.177713605651906

# %%
def valid(model, testing_loader):
    model.eval()
    eval_loss, eval_accuracy = 0, 0
    nb_eval_examples, nb_eval_steps = 0, 0
    eval_preds, eval_labels = [], []
    with torch.no_grad():
        for idx, batch in enumerate(testing_loader):
            ids = batch['ids'].to(device, dtype = torch.long)
            mask = batch['mask'].to(device, dtype = torch.long)
            targets = batch['targets'].to(device, dtype = torch.long)
            outputs = model(input_ids=ids, attention_mask=mask, labels=targets)
            loss, eval_logits = outputs.loss, outputs.logits
            eval_loss += loss.item()
            nb_eval_steps += 1
            nb_eval_examples += targets.size(0)
            if idx % 100==0:
                loss_step = eval_loss/nb_eval_steps
                print(f"Validation loss per 100 evaluation steps: {loss_step}")
            flattened_targets = targets.view(-1)
            active_logits = eval_logits.view(-1, model.num_labels)
            flattened_predictions = torch.argmax(active_logits, axis=1)
            active_accuracy = mask.view(-1) == 1
            targets = torch.masked_select(flattened_targets, active_accuracy)
            predictions = torch.masked_select(flattened_predictions, active_accuracy)
            eval_labels.extend(targets)
            eval_preds.extend(predictions)
            tmp_eval_accuracy = accuracy_score(targets.cpu().numpy(), predictions.cpu().numpy())
            eval_accuracy += tmp_eval_accuracy
    labels = [id2label[id.item()] for id in eval_labels]
    predictions = [id2label[id.item()] for id in eval_preds]
    eval_loss = eval_loss / nb_eval_steps
    eval_accuracy = eval_accuracy / nb_eval_steps
    print(f"Validation Loss: {eval_loss}")
    print(f"Validation Accuracy: {eval_accuracy}")
    return labels, predictions

# %%
labels, predictions = valid(model, testing_loader)
# Out:
# Validation loss per 100 evaluation steps: 0.07530897110700607
# Validation loss per 100 evaluation steps: 0.027080160601982053
# Validation loss per 100 evaluation steps: 0.02809819324234262
# Validation loss per 100 evaluation steps: 0.0276186210838664
# Validation loss per 100 evaluation steps: 0.026702008809218768
# Validation loss per 100 evaluation steps: 0.02528305164647652
# Validation loss per 100 evaluation steps: 0.02504513506985476
# Validation loss per 100 evaluation steps: 0.024622288027337933
# Validation loss per 100 evaluation steps: 0.024769341864139302
# Validation loss per 100 evaluation steps: 0.025274523587873
# Validation loss per 100 evaluation steps: 0.02522598159216918
# Validation loss per 100 evaluation steps: 0.025794290539347668
# Validation loss per 100 evaluation steps: 0.025922855626114693
# Validation loss per 100 evaluation steps: 0.025585819675504707
# Validation loss per 100 evaluation steps: 0.02576997882418077
# Validation loss per 100 evaluation steps: 0.025741308268215975
# Validation loss per 100 evaluation steps: 0.025482183875337763
# Validation loss per 100 evaluation steps: 0.025657379136548496
# Validation loss per 100 evaluation steps: 0.025468751448896303
# Validation loss per 100 evaluation steps: 0.025460945581737133
# Validation loss per 100 evaluation steps: 0.02557376227452059
# Validation loss per 100 evaluation steps: 0.02544567985833622
# Validation loss per 100 evaluation steps: 0.025658608258885583
# Validation loss per 100 evaluation steps: 0.02575674823447294
# Validation loss per 100 evaluation steps: 0.0257208837646219
# Validation loss per 100 evaluation steps: 0.025658532259504502
# Validation loss per 100 evaluation steps: 0.025765769913326703
# Validation loss per 100 evaluation steps: 0.025614994431458735
# Validation loss per 100 evaluation steps: 0.02562169746317129
# Validation loss per 100 evaluation steps: 0.025627198604569724
# Validation loss per 100 evaluation steps: 0.02559874617586415
# Validation loss per 100 evaluation steps: 0.025593402230749306
# Validation loss per 100 evaluation steps: 0.025776148306813802
# Validation loss per 100 evaluation steps: 0.025783092305906898
# Validation loss per 100 evaluation steps: 0.02584837349277693
# Validation loss per 100 evaluation steps: 0.025743762828406413
# Validation loss per 100 evaluation steps: 0.02563099042390339
# Validation loss per 100 evaluation steps: 0.025516125912608
# Validation loss per 100 evaluation steps: 0.02551330295832877
# Validation loss per 100 evaluation steps: 0.025484595773057464
# Validation loss per 100 evaluation steps: 0.02550360013733981
# Validation loss per 100 evaluation steps: 0.025516547930314454
# Validation loss per 100 evaluation steps: 0.02545136732450588
# Validation loss per 100 evaluation steps: 0.025380875678217216
# Validation loss per 100 evaluation steps: 0.025272720799644308
# Validation loss per 100 evaluation steps: 0.02521176214165149
# Validation loss per 100 evaluation steps: 0.025085403955090426
# Validation loss per 100 evaluation steps: 0.025172215250090463
# Validation Loss: 0.025214979977725777
# Validation Accuracy: 0.9619423547957985

# %%
from seqeval.metrics import classification_report
print(classification_report([labels], [predictions]))
# Out:
#               precision    recall  f1-score   support
#
#          geo       0.84      0.88      0.86     11232
#          gpe       0.94      0.92      0.93      3293
#          org       0.66      0.65      0.65      6531
#          per       0.69      0.81      0.75      5196
#          tim       0.85      0.83      0.84      4360
#
#    micro avg       0.79      0.81      0.80     30612
#    macro avg       0.80      0.82      0.81     30612
# weighted avg       0.79      0.81      0.80     30612

# %%
sentence = "India has a capital called Mumbai. On wednesday, the president will give a presentation"
inputs = tokenizer(sentence, padding='max_length', truncation=True, max_length=MAX_LEN, return_tensors="pt")
ids = inputs["input_ids"].to(device)
mask = inputs["attention_mask"].to(device)
outputs = model(ids, mask)
logits = outputs[0]
active_logits = logits.view(-1, model.num_labels)
flattened_predictions = torch.argmax(active_logits, axis=1)
tokens = tokenizer.convert_ids_to_tokens(ids.squeeze().tolist())
token_predictions = [id2label[i] for i in flattened_predictions.cpu().numpy()]
wp_preds = list(zip(tokens, token_predictions))
word_level_predictions = []
for pair in wp_preds:
  if (pair[0].startswith(" ##")) or (pair[0] in ['[CLS]', '[SEP]', '[PAD]']):
    continue
  else:
    word_level_predictions.append(pair[1])
str_rep = " ".join([t[0] for t in wp_preds if t[0] not in ['[CLS]', '[SEP]', '[PAD]']]).replace(" ##", "")
print(str_rep)
print(word_level_predictions)
# Out:
# india has a capital called mumbai . on wednesday , the president will give a presentation
# ['B-geo', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O', 'B-tim', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
from transformers import pipeline
pipe = pipeline(task="token-classification", model=model.to(device), tokenizer=tokenizer, aggregation_strategy="simple")
pipe("My name is Niels and New York is a city")
# Out:
# [{'entity_group': 'per',
#   'score': 0.77152693,
#   'word': 'ni',
#   'start': None,
#   'end': None},
#  {'entity_group': 'per',
#   'score': 0.7938871,
#   'word': '##els',
#   'start': None,
#   'end': None},
#  {'entity_group': 'geo',
#   'score': 0.9370308,
#   'word': 'new york',
#   'start': None,
#   'end': None}]

# %%
# !sudo apt-get install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
model_name = "bert-finetuned-ner-12mar"
tokenizer.push_to_hub(
    repo_id=model_name,
    organization="Keertss",
    commit_message="Add tokenizer",
    use_temp_dir=True,
)
model.push_to_hub(
    repo_id=model_name,
    organization="Keertss",
    commit_message="Add model",
    use_temp_dir=True,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:680: UserWarning: The `organization` argument is deprecated and will be removed in v5 of Transformers. Set your organization directly in the `repo_id` passed instead (`repo_id={organization}/{model_id}`).
#   warnings.warn(
# README.md:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Keertss/bert-finetuned-ner-12mar/commit/bcdee2ec7924b5e287aef803b1c7411cc3e9b120', commit_message='Add model', commit_description='', oid='bcdee2ec7924b5e287aef803b1c7411cc3e9b120', pr_url=None, pr_revision=None, pr_num=None)

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
model_name = "Keertss/bert-finetuned-ner-12mar"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.24k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
